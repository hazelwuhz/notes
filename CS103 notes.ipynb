# %% [markdown]
# ##### Lecture 0: set theory
#
# A set is an unordered collection of distinct objects, which may be anything, including other sets.
#
# Two sets are equal when they have the same contents, ignoring order.
#
# Sets cannot contain duplicate elements. Any repeated elements are ignored.
#
# The objects that make up a set are called the elements of that set.
#
# Sets can contain any number of elements.
#
# The empty set $\empty$ is the set with no elements.
#
# The set $\mathbb{N} = \{ 0, 1, 2, 3, …\}$ is the set of all the natural numbers.
#
# The set $\mathbb{Z} = \{ …, -2, -1, 0, 1, 2, … \}$ is the set of all the integers.
#
# The set $\mathbb{R}$ is the set of all real numbers.
#
# Union: $A\cup B$	Intersection: $A\cap B$
#
# Difference: $A-B$, $A\backslash B$
#
# Symmetric Difference: $A\triangle B$
#
# A set $S$ is called a subset of a set $T$ (denoted $S\subseteq T$) when all elements of S are also elements of T.
#
# We say that $S\in T$ when, among the elements of $T$, one of them is exactly the object $S$.
#
# We say that $S\subseteq T$ when $S$ is a set and every element of $S$ is also an element of $T$.
#
# $\wp(S)=\{T|T\subseteq S\}$ is the power set of $S$, the set of all subsets of $S$.
#
# The cardinality $|S|$ of a set $S$ is the number of elements it contains.
#
# ​	$|\mathbb{N}|=\mathbb{Z}|=\aleph_0$
#
# Cantor’s Theorem: If $S$ is a set, then $|S| < |\wp(S)|$.
#
# ##### Lecture 1: mathematical proofs
#
# Proofs: definitions, intuitions, conventions
#
# universally-quantified statement
#
# existentially-quantified statement
#
# direct proof:
#
# > Consider any …variables… such that …conditions…
# >
# > Assume … We need/want to show that …
# >
# > To do so, we consider two cases.
# >
# > In either case, we see that …, as required.
# >
# > Since …, there is/are some …variable(s)… such that …
# >
# > This means that …equation…
# >
# > Let …variables… equal …values…
# >
# > Therefore, …, which is what we wanted to show.
#
# ##### Lecture 2: indirect proofs
#
# A proposition is a statement that is either true or false.
#
# The negation of a proposition $X$ is a proposition that is true when $X$ is false and is false when $X$ is true.
#
# The negation of the universal statement “Every $P$ is a $Q$” is the existential statement “There is a $P$ that is not a $Q$”.
#
# The negation of the universal statement “For all $x$, $P(x)$ is true” is the existential statement “There exists a $x$ where $P(x)$ is false”.
#
# An implication is a statement of the form “If $P$ is true, then $Q$ is true.”
# $\text{antecedent}\to\text{consequent}$
#
# Negation of “For every $x$, if $P(x)$ is true, then $Q(x)$ is true”:
# 	“There is a $x$ where $P(x)$ is true and $Q(x)$ is false”.
#
# The contrapositive of the implication “If $P$ is true, then $Q$ is true” is the implication “If $Q$ is false, then $P$ is false”.
#
# Biconditionals: if and only if
#
# proof by contradiction:
#
# > Assume for the sake of contradiction that …
# >
# > We have reached a contradiction, so our assumption must have been wrong. Therefore, …
#
# Proof by contrapositive:
#
# > We will prove the contrapositive of this statement, that if …, then …
#
# ##### Lecture 3: propositional logic
#
# Each propositional variable stands for a proposition, something that is either true or false.
#
# Propositional connectives link propositions into larger propositions.
#
# logical negation: $\neg$
#
# logical conjunction: $\wedge$
#
# logical disjunction: $\vee$
#
# the “truth” connective: $\top$
#
# the “falsity” connective: $\perp$
#
# the material conditional (implication): $p\to q$
#
# the biconditional connective: $p \leftrightarrow q$
#
# An implication with a false antecedent is called vacuously true.
# An implication with a true consequent is called trivially true.
#
# A truth table is a table showing the truth value of a propositional logic formula as a function of its inputs.
#
# de Morgan’s laws:
#
# $\neg(p\wedge q)$ is equivalent to $\neg p \vee \neg q$
#
#  $\neg(p \vee q)$ is equivalent to $\neg p \and \neg q$
#
# Operator precedence for propositional logic: $\neg\quad\wedge\quad\vee\quad\to\quad\leftrightarrow$
#
# All operators are right-associative.
# $$
# \begin{array}{c|c}
# \text{connective}&\text{negation}\\\hline
# p\wedge q&\neg p \vee \neg q,p\to\neg q\\\hline
# p\vee q&\neg p \and \neg q\\\hline
# p\to q&p\wedge \neg q\\\hline
# p\leftrightarrow q&p\leftrightarrow\neg q,\neg p\leftrightarrow q
# \end{array}
# $$
#
# ##### Lectures 4, 5: first-order logic
#
# First-order logic is a logical system for reasoning about properties of objects.
#
# ​	• predicates that describe properties of objects
# ​	• functions that map objects to one another
# ​	• quantifiers that allow us to reason about multiple objects
#
# Unlike propositional variables, constant symbols refer to objects, not propositions.
#
# Predicates take objects as arguments and evaluate to true or false.
#
# the predicate =: Equality can only be applied to objects.
#
# Functions take objects as input and produce objects as output.
# 	Functions evaluate to objects, not propositions.
#
# the existential quantifier: $\exists$
#
# the universal quantifier: $\forall$
#
# Universally-quantified statements are said to be vacuously true in empty worlds.
#
# “Some $P$ is a $Q$” translates as $\exists x. (P(x) \wedge Q(x))$
#
# “All $P$s are $Q$s” translates as $\forall x. (P(x) \to Q(x))$
#
# “All $A$s are $B$s”	$\forall x. (A(x) \to B(x))$
#
# “Some $A$s are $B$s”	$\exists x. (A(x) \wedge B(x))$
#
# “No $A$s are $B$s”	$\forall x. (A(x) \to \neg B(x))$
#
# “Some $A$s aren’t $B$s”	$∃x. (A(x) \wedge \neg B(x))$
#
# Negations:
#
# $\forall x. P(x)$	vs	$\exists x. \neg P(x)$
#
# $\exists x. P(x)$	vs	$\forall x. \neg P(x)$
#
# ##### lectures 6, 7: functions
#
# ##### lecture 8: set theory
#
# ##### lectures 9, 10, 11: graphs
